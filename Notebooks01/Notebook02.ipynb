# %%
def say_hello(name):
    return 'Hello {0}'.format(name)

# %% [markdown]
# This is **very** important so pay attention!

# %% [markdown]
# # Code in Markdown:
#
# ```python
# def say_hello(name):
#     return 'Hello {0}'.format(name)
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
np.random.seed(15976)

# %%
SIZE=100
x = np.random.normal(size = SIZE)
x
# Out:
# array([ 1.45743535,  1.18434294,  0.38009475,  0.03752906,  0.38511108,
#        -0.93702259, -1.21114149,  0.1472935 , -0.61597235,  0.38679637,
#         0.83102226,  0.54209187,  0.26486154, -1.05132838,  0.70869963,
#         0.11989179,  0.94911672, -0.02737253,  0.55564913, -0.35810531,
#        -0.65582217,  0.32780219, -0.9219099 ,  0.40165996, -0.77361198,
#         1.2526741 , -1.26969328,  0.1903718 , -0.70983705,  0.60152535,
#        -0.40930043, -1.29909978, -0.76633698, -0.53558717,  3.66919636,
#        -0.24860217,  0.79271682,  0.46445711, -0.15272569, -0.13958047,
#         0.25589484,  1.27484469, -1.04689527, -0.11541469,  0.13134883,
#        -1.37365851,  0.05691795,  0.16458449, -0.50197671, -0.88005522,
#        -0.63900507, -0.34083879, -0.2248105 , -0.28667112,  1.11429278,
#         0.65787869, -0.88608239, -2.12417496,  0.36847244,  0.70435195,
#        -0.05314747, -0.08527043,  0.19518838,  0.66456685, -0.38038772,
#        -0.49280184,  0.56762198, -1.22024214,  0.67248318, -0.28279037,
#        -0.25918042,  0.29234276, -0.13881088,  1.83328581, -0.98596111,
#        -0.09166007,  0.89111763,  0.13259842, -2.31530638, -0.41417659,
#         0.37433086, -0.68106368, -0.10172356,  0.78404103, -1.1064475 ,
#        -0.91416824, -0.86230683,  2.3494592 , -0.69080535, -1.04751707,
#        -0.14635608, -1.61656902, -0.19278428, -0.22297036, -0.8904408 ,
#        -1.09222882, -0.70160774,  0.66245147,  0.98992995,  0.58943593])

# %%
plt.hist(x)
# Out:
# (array([ 2.,  6., 23., 26., 27., 12.,  2.,  1.,  0.,  1.]),
#  array([-2.31530638, -1.7168561 , -1.11840583, -0.51995556,  0.07849472,
#          0.67694499,  1.27539527,  1.87384554,  2.47229581,  3.07074609,
#          3.66919636]),
#  <a list of 10 Patch objects>)

# %%
S2 = 300
y = np.random.normal(size = S2)
yu = np.random.normal(size = S2)

# %%
plt.scatter(y,yu)
